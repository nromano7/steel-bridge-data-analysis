# %% [markdown]
# # Initializing the Notebook Working Environment
# The command below will initialize the environment with the necessary libararies and settings.

# %%
# %run initialize.py
# Out:
# Python version: 3.6.1 |Anaconda 4.4.0 (64-bit)| (default, May 11 2017, 13:25:24) [MSC v.1900 64 bit (AMD64)]
# pandas version: 0.20.1 name: pd
# NumPy version: 1.12.1 name: np
# SciPy version: 0.19.0 name: sp
# IPython version: 5.3.0
# scikit-learn version: 0.18.1
# matplotlib version: 2.0.2
# plotly version: 2.0.11

# %% [markdown]
# # The *dataset* module
# The *dataset* module contains methods for importing and working with the data.

# %%
import dataset as ds
dir(ds)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'load_dataset',
#  'pandas',
#  'sys']

# %% [markdown]
# # Loading datasets
# Load a dataset using the load_dataset method.

# %%
sample_data = ds.load_dataset('data/parameters_1.csv',filetype='csv',index_first_col=True)
sample_data.head()
sample_data.tail()
# Out:
#              suite   type  spans       length       width  n_lanes       skew  \
# ï»¿id
# Steel_1_1_1      1  Steel      1  1026.847164  775.438645        5  15.299095
# Steel_1_1_2      1  Steel      1   558.658584  551.265623        3   6.972710
# Steel_1_1_3      1  Steel      1  1261.266819  540.389853        3  48.101910
# Steel_1_1_4      1  Steel      1  1700.816141  757.401982        5   4.388740
# Steel_1_1_5      1  Steel      1  1883.786336  623.321910        4  26.390793
#
#              gdr_spacing  n_gdr  span2depth     ...       extgdr_llmneg  \
# ï»¿id                                           ...
# Steel_1_1_1   110.776949      8   26.685853     ...                 NaN
# Steel_1_1_2    91.877604      7   25.439707     ...                 NaN
# Steel_1_1_3   108.077971      6   24.417698     ...                 NaN
# Steel_1_1_4   126.233664      7   20.188046     ...                 NaN
# Steel_1_1_5   124.664382      6   28.524851     ...                 NaN
#
#                extgdr_dlv  extgdr_sdlv    extgdr_llv extgdr_ftgstress  \
# ï»¿id
# Steel_1_1_1   49638.54330  3610.009563  115710.40100     11999.408450
# Steel_1_1_2   22566.25811  2244.610384   89967.57794     11994.917320
# Steel_1_1_3   64961.59767  5912.188213  132195.89570     11855.338650
# Steel_1_1_4  114926.10330  6833.636286  147206.10610      6726.441984
# Steel_1_1_5  118056.81430  8830.248444  153273.98050     11715.765330
#
#              extgdr_st1rtgpos  extgdr_sv2rtgpos  extgdr_st1rtgneg  \
# ï»¿id
# Steel_1_1_1          1.970044          2.157130               NaN
# Steel_1_1_2          2.315147          2.484986               NaN
# Steel_1_1_3          2.230247          2.318027               NaN
# Steel_1_1_4          2.140183          1.740994               NaN
# Steel_1_1_5          1.915222          1.642793               NaN
#
#              extgdr_sv2rtgneg  extgdr_vrtg
# ï»¿id
# Steel_1_1_1               NaN     1.026571
# Steel_1_1_2               NaN     1.176911
# Steel_1_1_3               NaN     1.029945
# Steel_1_1_4               NaN     1.033236
# Steel_1_1_5               NaN     5.946888
#
# [5 rows x 77 columns]
#                suite   type  spans       length       width  n_lanes  \
# ï»¿id
# Steel_1_2_96       2  Steel      1  1333.619616  908.175472        6
# Steel_1_2_97       2  Steel      1  1617.442032  859.209418        5
# Steel_1_2_98       2  Steel      1  1835.447177  509.016283        3
# Steel_1_2_99       2  Steel      1  1770.014207  550.970271        3
# Steel_1_2_100      2  Steel      1  1686.431935  588.278102        4
#
#                     skew  gdr_spacing  n_gdr  span2depth     ...       \
# ï»¿id                                                        ...
# Steel_1_2_96   52.535240   129.739353      8   29.056528     ...
# Steel_1_2_97   57.854789   143.201570      7   24.770275     ...
# Steel_1_2_98   15.111772   127.254071      5   25.587606     ...
# Steel_1_2_99   50.275787    78.710039      8   20.240701     ...
# Steel_1_2_100   2.505389   117.655620      6   22.905166     ...
#
#                extgdr_llmneg    extgdr_dlv   extgdr_sdlv   extgdr_llv  \
# ï»¿id
# Steel_1_2_96             NaN   78964.54803   4688.506463  134569.8353
# Steel_1_2_97             NaN   95150.95162   6498.651029  143586.4879
# Steel_1_2_98             NaN  109595.88560  10324.390390  151411.4357
# Steel_1_2_99             NaN   81943.09409   6222.706195  149339.1828
# Steel_1_2_100            NaN   89714.14907   7905.149702  147009.8612
#
#               extgdr_ftgstress  extgdr_st1rtgpos  extgdr_sv2rtgpos  \
# ï»¿id
# Steel_1_2_96      11945.562170          1.861907          1.938355
# Steel_1_2_97      11999.998870          4.277044          4.373274
# Steel_1_2_98      11938.552570          1.799789          1.707790
# Steel_1_2_99       7778.452721          2.707244          2.173910
# Steel_1_2_100     11852.002270          2.006462          1.859629
#
#                extgdr_st1rtgneg  extgdr_sv2rtgneg  extgdr_vrtg
# ï»¿id
# Steel_1_2_96                NaN               NaN     1.029986
# Steel_1_2_97                NaN               NaN     6.168793
# Steel_1_2_98                NaN               NaN     1.108545
# Steel_1_2_99                NaN               NaN     1.034934
# Steel_1_2_100               NaN               NaN     1.041782
#
# [5 rows x 77 columns]

# %% [markdown]
# # Data fields and field descriptions
# *fields* contains descriptons of all of the fields in each of the datasets.

# %%
fields = ds.load_dataset('data/fields.csv',filetype='tsv',index_first_col=True)
fields
# Out:
#                                                               description
# field
# id                                         Model Identifier (Primary Key)
# suite                                                        Suite Number
# type                                                       Structure Type
# spans                                                     Number of Spans
# length                                                        Span Length
# width                                                  Total Bridge Width
# n_lanes                                                   Number of Lanes
# skew                                                          Bridge Skew
# gdr_spacing                                                Girder Spacing
# n_gdr                                                   Number of Girders
# span2depth                                            Span to Depth Ratio
# t_deck                                                     Deck Thickness
# n_dia                                                Number of Diaphragms
# dia_spacing                                             Diaphragm Spacing
# dia_type                                                   Diaphragm Type
# dia_section                                             Diaphragm Section
# intgdr_Ix                                      Interior Moment of Inertia
# intgdr_A                                            Interior Section Area
# intgdr_d                                           Interior Section Depth
# intgdr_tw                                          Interior Web Thickness
# intgdr_tf                                       Interior Flange Thickness
# intgdr_bf                                           Interior Flange Width
# intgdr_sectcomp                                  Interior Section Compact
# intgdr_flangecomp                                 Interior Flange Compact
# intgdr_webcomp                                       Interior Web Compact
# intgdr_mnpos                           Interior Positive Flexure Capacity
# intgdr_fnneg                           Interior Negative Flexure Capacity
# intgdr_vn                                         Interior Shear Capacity
# intgdr_dfm                            Interior Moment Distribution Factor
# intgdr_dfv                             Interior Shear Distribution Factor
# ...                                                                   ...
# DL2fb_ctrltol_LDpier    Superimposed Stress in Bottom Flange Load Mome...
# DL2fb_ctrltol_TD1pier   Superimposed Stress in Bottom Flange Load Mome...
# DL2fb_ctrltol_TD2pier   Superimposed Stress in Bottom Flange Load Mome...
# LLfb_ctrltol_LDpier     Live Load Stress in Bottom Flange at Location ...
# LLfb_ctrltol_TD1pier    Live Load Stress in Bottom Flange at Location ...
# LLfb_ctrltol_TD2pier    Live Load Stress in Bottom Flange at Location ...
# Settfb_ctrltol_LDpier   Sett. Moment at Stress in Bottom Flange of Con...
# Settfb_ctrltol_TD1pier  Sett. Moment at Stress in Bottom Flange of Con...
# Settfb_ctrltol_TD2pier  Sett. Moment at Stress in Bottom Flange of Con...
# DL1V_ctrltol_LDpier     Dead Load Shear at Location of Controlling Tol...
# DL1V_ctrltol_TD1pier    Dead Load Shear at Location of Controlling Tol...
# DL1V_ctrltol_TD2pier    Dead Load Shear at Location of Controlling Tol...
# DL2V_ctrltol_Ldpier     Superimposed Dead Load Shear at Location of Co...
# DL2V_ctrltol_TD1pier    Superimposed Dead Load Shear at Location of Co...
# DL2V_ctrltol_TD2pier    Superimposed Dead Load Shear at Location of Co...
# LLV_ctrltol_LDpier      Live Load Shear at Location of Controlling Tol...
# LLV_ctrltol_TD1pier     Live Load Shear at Location of Controlling Tol...
# LLV_ctrltol_TD2pier     Live Load Shear at Location of Controlling Tol...
# SettV_ctrltol_LDpier    Sett. Shear at Location of Controlling Toleran...
# SettV_ctrltol_TD1pier   Sett. Shear at Location of Controlling Toleran...
# SettV_ctrltol_TD2pier   Sett. Shear at Location of Controlling Toleran...
# loc_ctrlst1tol_LDpier   Location of Controlling Strength I Flexure Tol...
# loc_ctrlst1tol_TD1pier  Location of Controlling Strength I Flexure Tol...
# loc_ctrlst1tol_TD2pier  Location of Controlling Strength I Flexure Tol...
# loc_ctrlsv2tol_LDpier   Location of Controlling Service II Flexure Tol...
# loc_ctrlsv2tol_TD1pier  Location of Controlling Service II Flexure Tol...
# loc_ctrlsv2tol_TD2pier  Location of Controlling Service II Flexure Tol...
# loc_ctrlvtol_LDpier     Location of Controlling Strength I Shear Toler...
# loc_ctrlvtol_TD1pier    Location of Controlling Strength I Shear Toler...
# loc_ctrlvtol_TD2pier    Location of Controlling Strength I Shear Toler...
#
# [272 rows x 1 columns]

# %% [markdown]
# Get the full description for each field by querying the description column for the desired field identifier. This can be useful for labeling (e.g. labeling plot axes or labeling tables).

# %%
fields['description']['loc_ctrlvtol_TD2pier']
# Out:
# 'Location of Controlling Strength I Shear Tolerance for Transverse-Differential Movement Occuring at the Pier'

# %% [markdown]
# # Slicing the data

# %% [markdown]
# Get first 10 values of a specified column (e.g. span2depth), or multiple columns (e.g. length and span2depth).

# %%
sample_data['span2depth'].head(10)
sample_data[['length','span2depth']].head(10)
# Out:
# ï»¿id
# Steel_1_1_1     26.685853
# Steel_1_1_2     25.439707
# Steel_1_1_3     24.417698
# Steel_1_1_4     20.188046
# Steel_1_1_5     28.524851
# Steel_1_1_6     20.989849
# Steel_1_1_7     25.396747
# Steel_1_1_8     26.891057
# Steel_1_1_9     28.607862
# Steel_1_1_10    29.117310
# Name: span2depth, dtype: float64
#                    length  span2depth
# ï»¿id
# Steel_1_1_1   1026.847164   26.685853
# Steel_1_1_2    558.658584   25.439707
# Steel_1_1_3   1261.266819   24.417698
# Steel_1_1_4   1700.816141   20.188046
# Steel_1_1_5   1883.786336   28.524851
# Steel_1_1_6   1297.839121   20.989849
# Steel_1_1_7    708.880776   25.396747
# Steel_1_1_8   1678.226757   26.891057
# Steel_1_1_9   1774.485133   28.607862
# Steel_1_1_10   654.686459   29.117310

# %% [markdown]
# Filter the data (e.g. obtain samples with span length greater than 100ft).

# %%
gt_100ft = sample_data['length'] > 1200
sample_data['length'][gt_100ft].head()
# Out:
# ï»¿id
# Steel_1_1_3    1261.266819
# Steel_1_1_4    1700.816141
# Steel_1_1_5    1883.786336
# Steel_1_1_6    1297.839121
# Steel_1_1_8    1678.226757
# Name: length, dtype: float64

# %% [markdown]
# Get descriptive statistics for a specified column.

# %%
sample_data['n_lanes'].describe()
# Out:
# count    200.000000
# mean       3.970000
# std        0.907313
# min        2.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        6.000000
# Name: n_lanes, dtype: float64
